# %%
import pandas as pd
import numpy as np

# %%
food_balance = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv' ,encoding='ISO-8859–1')
food_balance.head(20)
# Out:
#     Area Code     Area  Item Code                      Item  Element Code  \
# 0           4  Algeria       2501                Population           511
# 1           4  Algeria       2501                Population          5301
# 2           4  Algeria       2901               Grand Total           664
# 3           4  Algeria       2901               Grand Total           674
# 4           4  Algeria       2901               Grand Total           684
# 5           4  Algeria       2903          Vegetal Products           664
# 6           4  Algeria       2903          Vegetal Products           674
# 7           4  Algeria       2903          Vegetal Products           684
# 8           4  Algeria       2941           Animal Products           664
# 9           4  Algeria       2941           Animal Products           674
# 10          4  Algeria       2941           Animal Products           684
# 11          4  Algeria       2905  Cereals - Excluding Beer          5511
# ...

# %%
food_balance.shape
# Out:
# (60943, 12)

# %%
food_balance.groupby('Element').sum().head(50)
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
food_balance.mean()
# Out:
# C:\Users\Peculiar Abolade\AppData\Local\Temp\ipykernel_15308\4138855164.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   food_balance.mean()
# Area Code        134.265576
# Item Code       2687.176706
# Element Code    3814.856456
# Y2014            134.196282
# Y2015            135.235966
# Y2016            136.555222
# Y2017            140.917765
# Y2018            143.758381
# dtype: float64

# %%
food_balance.std()
# Out:
# C:\Users\Peculiar Abolade\AppData\Local\Temp\ipykernel_15308\1014769833.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   food_balance.std()
# Area Code         72.605709
# Item Code        146.055739
# Element Code    2212.007033
# Y2014           1567.663696
# Y2015           1603.403984
# Y2016           1640.007194
# Y2017           1671.862359
# Y2018           1710.782658
# dtype: float64

# %%
food_balance.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
food_balance.nunique()
# Out:
# Area Code         49
# Area              49
# Item Code        122
# Item             119
# Element Code      18
# Element           18
# Unit               5
# Y2014           4493
# Y2015           4520
# Y2016           4520
# Y2017           4537
# Y2018           4591
# dtype: int64

# %%
food_balance.groupby('Item').sum().head(50)
# Out:
#                                  Area Code  Item Code  Element Code  \
# Item
# Alcohol, Non-Food                    38447     752497       1515090
# Alcoholic Beverages                  75016    1649136       2171381
# Animal Products                      18060     397035         90990
# Animal fats                          85279    1882494       2567303
# Apples and products                  69280    1352989       1920418
# Aquatic Animals, Others              47420     966381       1139179
# Aquatic Plants                       51178    1057275       1278386
# Aquatic Products, Other              52570    1160712       1320249
# Bananas                              68496    1338880       1894890
# Barley and products                  76321    1432410       2243002
# Beans                                78001    1476680       2263509
# Beer                                 65975    1314720       1813728
# Beverages, Alcoholic                 65918    1313052       1807946
# ...
